# %%
# pip install sentence-transformers scikit-learn numpy
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# 1) Canonical tags
beauty_accs = [
    'Хорошо пенится',
    'Деликатно очищает',
    'Удобный',
    'Отличный состав',
    'Для ночного ухода',
    'Высокая плотность',
    'Питает кожу',
    'Удлиняет ресницы',
    'Сужает поры',
    'Быстро расходуется',
    'Нежный',
    'Легкий аромат',
    'Не оставляет пленки',
    'Освежает лицо',
    'Не стягивает кожу',
    'Слабое отшелушивание',
    'Совместим с кремами',
    'Для сухих волос',
    'Выраженный эффект',
    'Для чувствительной кожи',
    'Не сушит',
    'Освежает дыхание',
    'Отличное качество',
    'Подсушивает',
    'Мягко очищает',
    'Даёт объём',
    'Увлажняет надолго',
]

len(beauty_accs)

# Чтобы не изменять bag_tags везде, передадим так
bag_tags = beauty_accs

# 3) загрузка модели (можно заменить на другую модель)
model = SentenceTransformer('deepvk/user-bge-m3')

# 4) вычисляем эмбеддинги canonical тегов (делаем один раз)
canon_emb = model.encode(bag_tags, convert_to_numpy=True, normalize_embeddings=True)

# 5) функция маппинга: возвращает top_k кандидатов и только те с similarity >= threshold
def map_raw_tags_with_embeddings(raw_tags, bag_tags, canon_emb, model,
                                 threshold=0.65, top_k=1, batch_size=32):
    """
    raw_tags: iterable of raw tag strings
    bag_tags: list canonical tags (same order as canon_emb)
    canon_emb: numpy array of canonical embeddings (L2-normalized)
    model: sentence-transformers model
    threshold: cosine similarity threshold (0..1)
    top_k: how many top candidates to return per raw tag
    returns: dict raw_tag -> list of (canonical_tag, similarity) sorted desc
    """
    results = {}
    # encode in batches
    for i in range(0, len(raw_tags), batch_size):
        batch = raw_tags[i:i+batch_size]
        emb = model.encode(batch, convert_to_numpy=True, normalize_embeddings=True)
        # cosine similarity matrix: (batch_size x n_canon)
        sims = np.dot(emb, canon_emb.T)  # because normalized, dot == cosine
        for j, raw in enumerate(batch):
            row = sims[j]
            # top_k indices
            idxs = np.argsort(-row)[:top_k]
            candidates = []
            for idx in idxs:
                score = float(row[idx])
                if score >= threshold:
                    candidates.append((bag_tags[idx], score))
            results[raw] = candidates  # empty list if nothing passed threshold
    return results
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/697 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.44G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/963 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]

# %%
import pandas as pd

# !gdown 1wwu3XmdLz7jQ5avywdLzKJkEEVkg7tru

# Имеющиеся

tags = pd.read_csv('/content/lamoda_reviews_sampled_with_tags.csv')
tags = tags[tags['tags'].notnull()]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wwu3XmdLz7jQ5avywdLzKJkEEVkg7tru
# To: /content/lamoda_reviews_sampled_with_tags.csv
# 100% 2.88M/2.88M [00:00<00:00, 224MB/s]

# %%
# Новые

beauty_tags = pd.read_csv('/content/beauty_llm_tags_1000_skus.csv')
beauty_tags = beauty_tags.rename(columns={'llm_tags': 'tags'})

beauty_tags
# Out:
#        product_sku                                       comment_text  \
# 0     AC001LMDWBR8  Запах кайф, текстура кайф\nприятно пахнет, увл...
# 1     AC001LWJOYF0  Отличная шутка . Жесткая . Но хватает надолго ...
# 2     AN042LWGLC72  Красивый цвет. Хорошие лаки, этот не первый и ...
# 3     AN042LWGLD12  Использую как базу и как финиш. Сохнет быстро,...
# 4     AN042LWIWK72  Хороший лак, к покупки рекомендую\nОтличный ла...
# ...            ...                                                ...
# 1207  XD001XW01780  Пришло с отломанным замочком. Цвет бледный, вы...
# 1208  XD001XW01CCS  потрясный аромат\nНе навязчивый стойкий\nАрома...
# 1209  XD001XW01CRL  Очень деликатное нанесение , без комков , не с...
# 1210  XD001XW01JAT  Запах приятный, пока тестирую\nДавно хотела по...
# 1211  XD001XW01O5F  Самый лучший скраб который я пробовала \nЛучши...
#
#                                                    tags
# 0     Плотная; приятный запах; рыхлая; сушит кожу; л...
# 1     Жесткая; Мягкая; Хорошо чистит; С чувствительн...
# 2     Быстро сохнет; Долго держится; Ровно ложится; ...
# 3     Глянцевое покрытие; быстро сохнет; укрепляет н...
# 4     Быстро сохнет; Ровно ложится; Долго держится; ...
# ...                                                 ...
# 1207  Замочок отломан; Цвет бледный; Надписи нет; Ка...
# 1208  Нежный; стеклянный; сирень; уютный; тёплый; лё...
# 1209  Без комков; Не склеивает; Уходовое действие; Н...
# 1210  Приятный запах; Качественная упаковка; Свежест...
# 1211  Очищает до скрипа; Не травмирует кожу; Малый р...
#
# [1212 rows x 3 columns]

# %%
cat_tags = tags[tags['good_type'] == 'Beauty_Accs']
cat_tags
# Out:
#        product_sku                                         comment_id  \
# 2     MP002XW0TITY  [429537120, 429326163, 431280940, 397131465, 4...
# 13    RTLABC980601  [383763719, 379895635, 378283967, 382568580, 4...
# 18    MP002XW1C416  [400201013, 417074349, 384972549, 429347734, 3...
# 19    RTLACB593301  [430416845, 422198645, 424541459, 392123166, 3...
# 22    MP002XU0D7UV  [413634621, 389281977, 379533936, 429321862, 3...
# ...            ...                                                ...
# 2636  MP002XW0AROG       [394188599, 390274771, 384279905, 384441378]
# 2644  MP002XW10ML2  [404522261, 378421858, 402992446, 420558774, 4...
# 2645  MP002XU002DN  [419739807, 407815173, 411530156, 399642221, 4...
# 2646  MP002XW0D54O       [378278645, 394993163, 381289517, 410214761]
# 2651  MP002XU0DWUM  [383570452, 426740658, 380434661, 402974005, 4...
#
#                                            comment_text  \
# 2     ["Хороший крем", "Крем понравился, хорошо увла...
# 13    ["Приятный запах, не липкое", "Губы увлажненны...
# 18    ["Отличный скраб, запах очень приятный, спасиб...
# 19    ["Оригинал! Цвет огонь!", "Классный блеск, пря...
# 22    ["Запах восхитительный. Средства свои функции ...
# ...                                                 ...
# 2636  ["Сыворотка очень нравиться!", "Брала в подаро...
# 2644  ["Отличнейший спрей. Наношу на слегка влажные ...
# 2645  ["люблю более выраженный вкус", "Пришло хорошо...
# 2646  ["Отличный крем, но вместо авокадо пришел бана...
# 2651  ["В начале пахнет лимоном)дальше хозяйственным...
#
#                                 name    good_type    good_subtype  \
# 2                       Крем для рук  Beauty_Accs      HANDS CARE
# 13                     Масло для губ  Beauty_Accs       LIPS CARE
# 18                    Скраб для тела  Beauty_Accs   BATH & SHOWER
# 19        Бальзам оттеночный для губ  Beauty_Accs    MAKE-UP LIPS
# 22         Набор для ухода за руками  Beauty_Accs      HANDS CARE
# ...                              ...          ...             ...
# 2636              Сыворотка для лица  Beauty_Accs       FACE CARE
# 2644                 Спрей для волос  Beauty_Accs       HAIR CARE
# 2645  Ополаскиватель для полости рта  Beauty_Accs       ORAL CARE
# 2646       Набор для ухода за руками  Beauty_Accs      HANDS CARE
# 2651                    Мыло твердое  Beauty_Accs  FACE CLEANSING
#
#                                                    tags
# 2     Хорошо увлажняет; Питает; Впитывается быстро; ...
# 13    Не липкое; Увлажняет; Насыщенный цвет; Приятны...
# 18    Приятный аромат; Увлажняет кожу; Ненавязчивый ...
# 19    Нейтральный оттенок; Перламутровый оттенок; По...
# 22    Увлажняет хорошо; Быстро впитывается; Приятная...
# ...                                                 ...
# 2636       Хорошо увлажняет; Высокое качество; Оригинал
# 2644  Приятный аромат; Увлажняет волосы; Облегчает р...
# 2645  Концентрат; Освежающий; Не пенится; Приятный в...
# 2646  Быстро впитывается; Не оставляет жирности; Не ...
# 2651  Пахнет лимоном; Запах хозяйственного мыла; Быс...
#
# [619 rows x 7 columns]

# %%
# Конкат

tags = (
    pd.concat([cat_tags, beauty_tags], ignore_index=True)
      .drop_duplicates()
)
tags = tags.drop(columns = ['comment_id', 'name', 'good_type', 'good_subtype'])

# %%
dataset = []

for _, item in tags.iterrows():
    tag_list = [tag.strip() for tag in str(item['tags']).split(';') if tag.strip()]
    dataset.append((item['comment_text'], tag_list))

# %%
dataset[0][1]
# Out:
# ['Хорошо увлажняет',
#  'Питает',
#  'Впитывается быстро',
#  'Не липкий',
#  'Приятный аромат',
#  'Не навязчивый аромат',
#  'Не жирный',
#  'Смягчает',
#  'Для лета',
#  'Большой объем',
#  'Парфюмированный']

# %%
dataset[0][0]
# Out:
# '["Хороший крем", "Крем понравился, хорошо увлажняет и питает, впитывается быстро", "Запах приятный ,хорошо впитывается  ", "Крем замечательный, впитывается быстро, не липкий, рекомендую", "Неплохой крем. Не жирный. Смягчает,  но не увлажняет. Для лета хорошо,  но для зимы нужно пожирнее.", " Большой объем, хорошо увлажняет, приятный не навязчивый аромат.", "Очень парфюмированный и  эффект не понравился"]'

# %%
len(dataset)
# Out:
# 1831

# %%
# пример использования

final = []

for i in range(len(dataset)):
    # Берем raw tag датасета
    raw_tags = dataset[i][1]
    mapped = map_raw_tags_with_embeddings(raw_tags, bag_tags, canon_emb, model,
                                        threshold=0.7, top_k=1)

    tags_to_send = []
    for r, cands in mapped.items():
        tag = cands[0][0] if cands else None
        if tag != None:
            tags_to_send.append(tag)
        print(r, "->", cands, tag)

    if tags_to_send:
        final.append((dataset[i][0], list(set(tags_to_send))))
    print()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# Хорошее масло -> [] None
# Подходит для баночного массажа -> [] None
# Дренажный массаж -> [] None
#
# Легкий -> [('Удобный', 0.723291277885437)] Удобный
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Без пленки -> [] None
# Подходит для сухой кожи -> [('Для сухих волос', 0.8075948357582092)] Для сухих волос
# Пользуется часто -> [] None
#
# Быстро впитывается -> [('Быстро расходуется', 0.7235442399978638)] Быстро расходуется
# Уменьшает черные точки -> [('Мягко очищает', 0.7162291407585144)] Мягко очищает
# Подсушивает воспаления -> [('Подсушивает', 0.7453091144561768)] Подсушивает
#
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# Хорошо пенится -> [('Хорошо пенится', 0.9999998807907104)] Хорошо пенится
# Без химии -> [] None
# Не вызывает зуда -> [] None
# Неприятный аромат -> [] None
# Появилась перхоть -> [] None
# Планируется ежедневное использование -> [] None
#
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# Пенится -> [('Хорошо пенится', 0.7435770034790039)] Хорошо пенится
# Пахнет травами -> [('Легкий аромат', 0.7029210329055786)] Легкий аромат
# Укладывается -> [('Подсушивает', 0.7426561117172241)] Подсушивает
# Объем -> [('Даёт объём', 0.7576044201850891)] Даёт объём
# Не утяжеляет -> [('Мягко очищает', 0.7067421674728394)] Мягко очищает
#
# Эффективный -> [] None
# Удобный -> [('Удобный', 1.0)] Удобный
# Очищает -> [('Деликатно очищает', 0.8635239601135254)] Деликатно очищает
# Массаж -> [] None
# Подходит с гелем -> [('Совместим с кремами', 0.7800024747848511)] Совместим с кремами
# Работает -> [('Даёт объём', 0.7298365235328674)] Даёт объём
# Разряжается быстро -> [('Быстро расходуется', 0.8973740339279175)] Быстро расходуется
# Тупит -> [] None
# Сложно включить -> [] None
# Эргономичный -> [('Удобный', 0.8290013074874878)] Удобный
# Улучшает кожу -> [('Питает кожу', 0.8093631267547607)] Питает кожу
# Сияет -> [('Освежает лицо', 0.7136765122413635)] Освежает лицо
# Освежает -> [('Освежает дыхание', 0.927131712436676)] Освежает дыхание
# Домашний уход -> [('Для ночного ухода', 0.7235164642333984)] Для ночного ухода
# Заменяет косметолога -> [] None
#
# Жидкая текстура -> [] None
# Суховат -> [] None
# Быстро впитывается -> [('Быстро расходуется', 0.7235442399978638)] Быстро расходуется
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# Легкий -> [('Удобный', 0.723291277885437)] Удобный
# Не подходит для осветленных волос -> [('Не стягивает кожу', 0.7046114802360535)] Не стягивает кожу
#
# Сильный пилинг -> [] None
# вызывает ожог -> [] None
# шелушение -> [] None
# гладкая кожа -> [('Мягко очищает', 0.7037788033485413)] Мягко очищает
# чувствительная кожа -> [('Для чувствительной кожи', 0.903185248374939)] Для чувствительной кожи
# эффективен -> [('Выраженный эффект', 0.721892774105072)] Выраженный эффект
# справляется с постакне -> [('Освежает лицо', 0.7161002159118652)] Освежает лицо
# вызывает красноту -> [] None
# не вызывает аллергии -> [] None
# приятный запах -> [('Легкий аромат', 0.8495475053787231)] Легкий аромат
# требует осторожности -> [] None
# подходит для домашнего использования -> [('Удобный', 0.724443256855011)] Удобный
# эффект после 10 минут -> [] None
# убирает следы фотостарения -> [('Освежает лицо', 0.732917070388794)] Освежает лицо
# сочетается с красным пилингом -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851033449172974)] Увлажняет надолго
# освежает -> [('Освежает дыхание', 0.9279190301895142)] Освежает дыхание
# подтягивает -> [('Даёт объём', 0.7862062454223633)] Даёт объём
# не липкая -> [('Не стягивает кожу', 0.7258011698722839)] Не стягивает кожу
# с кофеином -> [] None
# среднее качество -> [] None
# помогает от отеков -> [] None
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# непривычный цвет -> [] None
#
# Мягкий -> [('Нежный', 0.8240550756454468)] Нежный
# Стойкий цвет -> [] None
# Не течет -> [('Не сушит', 0.745932936668396)] Не сушит
# Не сыпется -> [('Не стягивает кожу', 0.7399518489837646)] Не стягивает кожу
#
# Лёгкая текстура -> [('Легкий аромат', 0.767508864402771)] Легкий аромат
# Увлажняет -> [('Увлажняет надолго', 0.8851031064987183)] Увлажняет надолго
# Без липкости -> [] None
# Подходит под макияж -> [('Освежает лицо', 0.7525302171707153)] Освежает лицо
#
# Не сушит волосы -> [('Не сушит', 0.8214005827903748)] Не сушит
# живые кудри -> [] None
# клейкий -> [] None
# держит кудряшки -> [] None
# нейтральный аромат -> [('Легкий аромат', 0.7805162668228149)] Легкий аромат
# малый расход -> [] None
#
# Желтоватый оттенок -> [] None
# Естественный цвет -> [] None
# Легкий загар -> [('Легкий аромат', 0.7369475364685059)] Легкий аромат
# Плотная текстура -> [('Высокая плотность', 0.738075852394104)] Высокая плотность
# Прекрасный аромат -> [('Легкий аромат', 0.7939660549163818)] Легкий аромат
# Поддерживает загар -> [('Освежает лицо', 0.705986499786377)] Освежает лицо
#
# Эффективный -> [] None
# уменьшает высыпания -> [] None
# гладкая кожа -> [('Мягко очищает', 0.703778862953186)] Мягко очищает
# мягкий -> [('Нежный', 0.7993518710136414)] Нежный
# без покраснения -> [] None
# увлажняет -> [('Увлажняет надолго', 0.8867706656455994)] Увлажняет надолго
# для жирной кожи -> [('Для чувствительной кожи', 0.7961556911468506)] Для чувствительной кожи
# для подростков -> [] None
# не вызывает раздражения -> [] None
# хорошее качество -> [('Отличное качество', 0.9332897663116455)] Отличное качество
# приятный запах -> [('Легкий аромат', 0.8495475649833679)] Легкий аромат
# работает -> [('Даёт объём', 0.7151600122451782)] Даёт объём
# не сушит -> [('Не сушит', 0.9489970207214355)] Не сушит
# энзимная пудра -> [] None
# щиплет -> [] None
# плохо набирается -> [('Слабое отшелушивание', 0.7187326550483704)] Слабое отшелушивание
# густой -> [] None
# плохая пипетка -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# работает по назначению -> [('Даёт объём', 0.7121349573135376)] Даёт объём
# разогревающий эффект -> [] None
#
# Холодный оттенок -> [] None
# мягкий -> [('Нежный', 0.7993518114089966)] Нежный
# матовый -> [] None
# держится долго -> [('Увлажняет надолго', 0.824768602848053)] Увлажняет надолго
# естественный цвет -> [] None
# спокойный цвет -> [] None
# качественный -> [('Отличное качество', 0.8470579981803894)] Отличное качество
#
# Блестки -> [] None
# Увлажняет -> [('Увлажняет надолго', 0.8851031064987183)] Увлажняет надолго
# Сливовый цвет -> [] None
# Липкий -> [] None
# Впитывается быстро -> [('Быстро расходуется', 0.7269394993782043)] Быстро расходуется
# Недостаточно продукта -> [] None
# Бледный оттенок -> [] None
# Прозрачный с цветом -> [] None
# Долго держится -> [('Увлажняет надолго', 0.8078199028968811)] Увлажняет надолго
# Яркий цвет -> [('Освежает лицо', 0.725551426410675)] Освежает лицо
# Сушит губы -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Заживляет -> [('Освежает дыхание', 0.7511621713638306)] Освежает дыхание
# Предотвращает трещины -> [] None
# Для сосков -> [] None
#
# Идеальный подарок -> [] None
# Набор в дорогу -> [] None
# Мини формат -> [] None
# Удобно везти -> [('Удобный', 0.7914584875106812)] Удобный
#
# Мягкие кисти -> [('Нежный', 0.7216658592224121)] Нежный
# Нейлон -> [] None
# Кора в рваной коробке -> [] None
# Для детей -> [] None
# Не качественный -> [] None
# Дороговато -> [] None
#
# Не сушит кожу -> [('Не стягивает кожу', 0.7761118412017822)] Не стягивает кожу
# хорошо очищает -> [('Деликатно очищает', 0.9035396575927734)] Деликатно очищает
# хорошо пенится -> [('Хорошо пенится', 0.9860424995422363)] Хорошо пенится
# отшелушивает -> [('Подсушивает', 0.764405369758606)] Подсушивает
# подходит для чувствительной кожи -> [('Для чувствительной кожи', 0.9347741007804871)] Для чувствительной кожи
# экономичный расход -> [] None
# деликатный состав -> [] None
# очищает от черных точек -> [('Деликатно очищает', 0.7508697509765625)] Деликатно очищает
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Легкий -> [('Удобный', 0.723291277885437)] Удобный
# Не оставляет следов -> [('Не оставляет пленки', 0.8116406202316284)] Не оставляет пленки
# Хорошо впитывается -> [('Увлажняет надолго', 0.7607879042625427)] Увлажняет надолго
# Пятка с мехом -> [] None
#
# Легкий -> [('Удобный', 0.723291277885437)] Удобный
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Быстро впитывается -> [('Быстро расходуется', 0.7235440015792847)] Быстро расходуется
# Без липкости -> [] None
# Приятный аромат -> [('Легкий аромат', 0.8724752068519592)] Легкий аромат
# Не блестит -> [('Не стягивает кожу', 0.7339804172515869)] Не стягивает кожу
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Легкая текстура -> [('Легкий аромат', 0.7788516879081726)] Легкий аромат
# Для чувствительной кожи -> [('Для чувствительной кожи', 1.0000001192092896)] Для чувствительной кожи
# Без липкости -> [] None
# Пользуется на сухой коже -> [('Для сухих волос', 0.7964268922805786)] Для сухих волос
#
# Мягкие волосы -> [('Для сухих волос', 0.720717191696167)] Для сухих волос
# Промывает хорошо -> [('Деликатно очищает', 0.7354042530059814)] Деликатно очищает
# Без зуда -> [] None
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Универсальный аромат -> [('Легкий аромат', 0.7228939533233643)] Легкий аромат
# Не сушит -> [('Не сушит', 1.000000238418579)] Не сушит
# Разглаживает -> [('Мягко очищает', 0.7622421979904175)] Мягко очищает
# Легко укладывается -> [('Удобный', 0.7514020204544067)] Удобный
# Презентабельная упаковка -> [] None
# Идеальный подарок -> [] None
# Хорошее качество -> [('Отличное качество', 0.9373326897621155)] Отличное качество
# Не утяжеляет -> [('Мягко очищает', 0.7067422866821289)] Мягко очищает
# Не пачкается -> [('Не сушит', 0.7440555095672607)] Не сушит
# Умеренный расход -> [] None
# Стабильный результат -> [] None
#
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# подсушивает -> [('Подсушивает', 0.923170804977417)] Подсушивает
# для чувствительной кожи -> [('Для чувствительной кожи', 0.991466224193573)] Для чувствительной кожи
# вызывает раздражение -> [] None
# уменьшает воспаления -> [] None
# мягкая пена -> [] None
# нейтральный запах -> [('Легкий аромат', 0.7630836963653564)] Легкий аромат
# сушит кожу -> [('Подсушивает', 0.7074086666107178)] Подсушивает
#
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# смягчает кожу -> [('Питает кожу', 0.7560698986053467)] Питает кожу
# пенится хорошо -> [('Хорошо пенится', 0.9188570380210876)] Хорошо пенится
# мягкая пена -> [] None
# эстетичная упаковка -> [] None
# подходит в подарок -> [] None
#
# Шелковистые волосы -> [] None
# Ненавязчивый аромат -> [('Легкий аромат', 0.8496233820915222)] Легкий аромат
# Гладкие волосы -> [('Для сухих волос', 0.719171404838562)] Для сухих волос
# Упаковка аккуратная -> [('Деликатно очищает', 0.7177615165710449)] Деликатно очищает
# Повреждена упаковка -> [] None
# Протекание шампуня -> [] None
# Сломанная крышка -> [] None
# Экономичный расход -> [] None
# Объем волос -> [] None
# Красивый шоппер -> [] None
#
# Лёгкая текстура -> [('Легкий аромат', 0.767508864402771)] Легкий аромат
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Хорошо впитывается -> [('Увлажняет надолго', 0.7607879638671875)] Увлажняет надолго
# Питает -> [('Питает кожу', 0.807714581489563)] Питает кожу
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Нежная текстура -> [('Нежный', 0.7934879064559937)] Нежный
# Супер состав -> [('Отличный состав', 0.7334843277931213)] Отличный состав
# Упаковка удобная -> [('Удобный', 0.8105878233909607)] Удобный
# Помпа не работает -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Гладкая кожа -> [('Мягко очищает', 0.7173491716384888)] Мягко очищает
# Без липкости -> [] None
# Легкий крем -> [('Легкий аромат', 0.7429102063179016)] Легкий аромат
# Справляется с куперозом -> [] None
# Хорошо впитывается -> [('Увлажняет надолго', 0.7607879042625427)] Увлажняет надолго
#
# Питательный -> [] None
# для чувствительной кожи -> [('Для чувствительной кожи', 0.991466224193573)] Для чувствительной кожи
# легкий -> [('Легкий аромат', 0.7364282608032227)] Легкий аромат
# без жирного блеска -> [] None
# с увлажняющим эффектом -> [('Увлажняет надолго', 0.8324010968208313)] Увлажняет надолго
#
# Плотная -> [] None
# увлажняет -> [('Увлажняет надолго', 0.8867708444595337)] Увлажняет надолго
# сияет -> [('Освежает лицо', 0.7175905108451843)] Освежает лицо
# питает -> [('Питает кожу', 0.8369655609130859)] Питает кожу
# низкий расход -> [] None
# без раздражения -> [] None
# для зимы -> [] None
# с ретинолом -> [] None
# натуральный состав -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# быстро впитывается -> [('Быстро расходуется', 0.7204931378364563)] Быстро расходуется
# скольжение -> [] None
# без дозатора -> [] None
#
# Хорошо пенится -> [('Хорошо пенится', 0.9999998807907104)] Хорошо пенится
# Очищает кожу -> [('Мягко очищает', 0.8311936259269714)] Мягко очищает
# Не сушит -> [('Не сушит', 1.000000238418579)] Не сушит
# Мягкий пилинг -> [('Мягко очищает', 0.7520169019699097)] Мягко очищает
# Приятный аромат -> [('Легкий аромат', 0.8724752068519592)] Легкий аромат
# Подходит для сухой кожи -> [('Для сухих волос', 0.8075947761535645)] Для сухих волос
#
# Увлажненная -> [('Увлажняет надолго', 0.7463761568069458)] Увлажняет надолго
# быстро пенится -> [('Хорошо пенится', 0.8466373085975647)] Хорошо пенится
# без раздражения -> [] None
# хорошее качество -> [('Отличное качество', 0.933289647102356)] Отличное качество
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# быстро впитывается -> [('Быстро расходуется', 0.7204931378364563)] Быстро расходуется
# без аллергии -> [] None
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# не оставляет жирного блеска -> [('Не оставляет пленки', 0.7346295118331909)] Не оставляет пленки
# хорошая текстура -> [('Отличное качество', 0.7323081493377686)] Отличное качество
# подходит для чувствительной кожи -> [('Для чувствительной кожи', 0.9347741007804871)] Для чувствительной кожи
# экономичный расход -> [] None
#
# Гладкая кожа -> [('Мягко очищает', 0.7173491716384888)] Мягко очищает
# Застывает -> [('Подсушивает', 0.789499044418335)] Подсушивает
# Наносить быстро -> [('Быстро расходуется', 0.7101080417633057)] Быстро расходуется
# Эффект насыщенный -> [('Выраженный эффект', 0.7541660070419312)] Выраженный эффект
#
# Не вызывает раздражение -> [] None
# Подходит для чувствительной кожи -> [('Для чувствительной кожи', 0.9406930804252625)] Для чувствительной кожи
# Убирает следы воспалений -> [('Мягко очищает', 0.7314555048942566)] Мягко очищает
# Смягчает кожу -> [('Мягко очищает', 0.7951496839523315)] Мягко очищает
# Мягкий запах -> [('Легкий аромат', 0.9398337602615356)] Легкий аромат
#
# Сильный аромат -> [('Легкий аромат', 0.7421970963478088)] Легкий аромат
# Мягкая текстура -> [('Мягко очищает', 0.7483992576599121)] Мягко очищает
# Стильная упаковка -> [('Отличное качество', 0.7056061029434204)] Отличное качество
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Стойкий запах -> [] None
# Резкий запах -> [] None
# Красивый дизайн -> [('Отличное качество', 0.7297383546829224)] Отличное качество
# Для подарка -> [] None
# Не насыщенный запах -> [('Легкий аромат', 0.7542568445205688)] Легкий аромат
#
# Хорошо пенится -> [('Хорошо пенится', 0.9999998807907104)] Хорошо пенится
# хорошо промывает -> [('Деликатно очищает', 0.8358564376831055)] Деликатно очищает
# волосы не спутываются -> [('Не сушит', 0.7372365593910217)] Не сушит
# мягкие волосы -> [('Для сухих волос', 0.7089811563491821)] Для сухих волос
# приятный запах -> [('Легкий аромат', 0.8495476245880127)] Легкий аромат
#
# Увлажняет -> [('Увлажняет надолго', 0.8851031064987183)] Увлажняет надолго
# Легко впитывается -> [] None
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Плохо липкое -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Освежает обувь -> [('Освежает дыхание', 0.7709270715713501)] Освежает дыхание
#
# Увлажняют -> [('Увлажняет надолго', 0.8593924045562744)] Увлажняет надолго
# снимают отек -> [] None
# не сползают -> [('Не сушит', 0.7226356267929077)] Не сушит
# разглаживают -> [('Освежает лицо', 0.757274329662323)] Освежает лицо
# плотные -> [('Высокая плотность', 0.7594230771064758)] Высокая плотность
# пропитанные -> [] None
# эссенция скатывается -> [] None
#
# Легкая текстура -> [('Легкий аромат', 0.7788516879081726)] Легкий аромат
# без блеска -> [] None
# не пачкает -> [('Не сушит', 0.7644907832145691)] Не сушит
# естественный загар -> [] None
# ровно ложится -> [] None
# для жирной кожи -> [('Для чувствительной кожи', 0.796155571937561)] Для чувствительной кожи
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# смягчает кожу -> [('Питает кожу', 0.7560698986053467)] Питает кожу
# жирное средство -> [] None
# липкая пленка -> [] None
# наносить ночью -> [('Для ночного ухода', 0.7842506766319275)] Для ночного ухода
#
# Прозрачный -> [] None
# не растекается -> [('Не стягивает кожу', 0.736111044883728)] Не стягивает кожу
# держится хорошо -> [('Увлажняет надолго', 0.7074372172355652)] Увлажняет надолго
# смягчает -> [('Подсушивает', 0.765911340713501)] Подсушивает
# сильный аромат -> [('Легкий аромат', 0.7133575677871704)] Легкий аромат
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# не липкий -> [('Не стягивает кожу', 0.7257087826728821)] Не стягивает кожу
# быстро впитывается -> [('Быстро расходуется', 0.7204931378364563)] Быстро расходуется
# питательный -> [] None
# плотная текстура -> [('Высокая плотность', 0.7916224002838135)] Высокая плотность
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# убирает морщины -> [('Освежает лицо', 0.727181077003479)] Освежает лицо
# удобный аппликатор -> [('Удобный', 0.7575026154518127)] Удобный
# подходит для сухой кожи -> [('Для сухих волос', 0.8051611185073853)] Для сухих волос
#
# Большие патчи -> [] None
# Увлажняют -> [('Увлажняет надолго', 0.8593924045562744)] Увлажняет надолго
# Не сползают -> [('Не сушит', 0.7279306054115295)] Не сушит
# Для чувствительной кожи -> [('Для чувствительной кожи', 1.0000001192092896)] Для чувствительной кожи
# Плотный гель -> [] None
# Снимают отёки -> [] None
# Разглаживают маршiny -> [] None
#
# Густой -> [] None
# приятный аромат -> [('Легкий аромат', 0.8658908605575562)] Легкий аромат
# экономичен -> [('Удобный', 0.700782299041748)] Удобный
# не сушит кожу -> [('Не сушит', 0.7943794131278992)] Не сушит
#
# Увлажняют хорошо -> [('Увлажняет надолго', 0.8745160698890686)] Увлажняет надолго
# скатываются -> [] None
# прилипают с течением времени -> [] None
#
# На подарок -> [] None
# Хорошая упаковка -> [('Отличное качество', 0.7535033226013184)] Отличное качество
# Запах хороший -> [('Легкий аромат', 0.8087812662124634)] Легкий аромат
#
# Мягкие волосы -> [('Для сухих волос', 0.720717191696167)] Для сухих волос
# Лёгкий аромат -> [('Легкий аромат', 0.977092981338501)] Легкий аромат
# Содержит церамиды -> [] None
#
# Пудровый -> [] None
# сладкий -> [] None
# средняя стойкость -> [] None
# быстро пачкается -> [('Быстро расходуется', 0.8179173469543457)] Быстро расходуется
# упаковка не качественная -> [] None
# не стойкий -> [('Не стягивает кожу', 0.739240288734436)] Не стягивает кожу
#
# Ощутимый массаж -> [] None
# Хорошая мощность -> [('Даёт объём', 0.742583155632019)] Даёт объём
# Хорошо всасывает -> [('Увлажняет надолго', 0.753768265247345)] Увлажняет надолго
# Насадка отваливается -> [] None
# Не удобен в руке -> [('Не стягивает кожу', 0.7387046813964844)] Не стягивает кожу
#
# Пенится сильно -> [('Хорошо пенится', 0.7095760107040405)] Хорошо пенится
# приятный аромат -> [('Легкий аромат', 0.8658908605575562)] Легкий аромат
# хорошо очищает -> [('Деликатно очищает', 0.9035395383834839)] Деликатно очищает
# сушит длину -> [('Подсушивает', 0.7411410808563232)] Подсушивает
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# мягкие волосы -> [('Для сухих волос', 0.7089811563491821)] Для сухих волос
# смывается легко -> [('Мягко очищает', 0.8442515134811401)] Мягко очищает
# помогает от выпадения -> [] None
# натуральный состав -> [] None
# тугая закрывашка -> [] None
# мускусный запах -> [('Легкий аромат', 0.7867227792739868)] Легкий аромат
#
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Очищает -> [('Деликатно очищает', 0.8635239601135254)] Деликатно очищает
# Мало пены -> [('Слабое отшелушивание', 0.7177488803863525)] Слабое отшелушивание
# Кратковременный эффект -> [] None
#
# Сильный пигмент -> [] None
# хорошо накладываются -> [('Даёт объём', 0.7054398059844971)] Даёт объём
# не скатываются -> [('Не сушит', 0.7208133339881897)] Не сушит
# универсальные -> [] None
#
# Холодный оттенок -> [] None
# хорошо растушевывается -> [('Даёт объём', 0.7065865397453308)] Даёт объём
# не рыжит -> [('Не сушит', 0.718937873840332)] Не сушит
# легкий -> [('Легкий аромат', 0.7364282608032227)] Легкий аромат
# деликатный -> [('Нежный', 0.7582911849021912)] Нежный
# красивый цвет -> [('Освежает лицо', 0.7149659395217896)] Освежает лицо
# не пылит -> [] None
# не оставляет пятен -> [('Мягко очищает', 0.7187913656234741)] Мягко очищает
#
# Легко впитывается -> [] None
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Без запаха -> [] None
# Не жирный -> [] None
# Хорошая защита -> [] None
# Мягкая текстура -> [('Мягко очищает', 0.7483994364738464)] Мягко очищает
# Нет белых следов -> [] None
#
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# Лёгкая консистенция -> [('Легкий аромат', 0.7424023151397705)] Легкий аромат
# Утяжеляет волосы -> [] None
# Не рекомендуется -> [] None
#
# Красивый цвет -> [('Освежает лицо', 0.7278209924697876)] Освежает лицо
# Равномерно наносятся -> [] None
# Долго держатся -> [('Увлажняет надолго', 0.79369056224823)] Увлажняет надолго
# Мерцание -> [] None
# Не слишком яркие -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.885103166103363)] Увлажняет надолго
# Жидковата -> [] None
# Не работает -> [] None
# Плотная текстура желательна -> [] None
# Без аллергии -> [] None
# Хорошо впитывается -> [('Увлажняет надолго', 0.7607879638671875)] Увлажняет надолго
# Снимает отечность -> [('Мягко очищает', 0.7263349294662476)] Мягко очищает
#
# Очищает -> [('Деликатно очищает', 0.8635239005088806)] Деликатно очищает
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Мягкий -> [('Нежный', 0.8240550756454468)] Нежный
# Пятка с мехом -> [] None
# Приятный аромат -> [('Легкий аромат', 0.8724752068519592)] Легкий аромат
# Подходит для возрастной кожи -> [('Для чувствительной кожи', 0.7397246956825256)] Для чувствительной кожи
# Не вызывает раздражений -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Очищает до скрипа -> [('Деликатно очищает', 0.7737042307853699)] Деликатно очищает
# Сушит кожу -> [('Питает кожу', 0.7244330644607544)] Питает кожу
#
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Лёгкий -> [('Удобный', 0.7076922059059143)] Удобный
# Блестит -> [] None
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Неровно ложится -> [('Подсушивает', 0.7061572670936584)] Подсушивает
# Скатывается -> [('Подсушивает', 0.7115834951400757)] Подсушивает
# Не увлажняет -> [('Не стягивает кожу', 0.83659428358078)] Не стягивает кожу
# Химозный аромат -> [] None
# Для макияжа -> [('Для чувствительной кожи', 0.7177554368972778)] Для чувствительной кожи
# Тонизирует -> [('Освежает дыхание', 0.7763283252716064)] Освежает дыхание
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Нежная текстура -> [('Нежный', 0.7934879064559937)] Нежный
# Мелкие частички -> [] None
# Очищает кожу -> [('Мягко очищает', 0.8311936855316162)] Мягко очищает
# Без раздражения -> [] None
# Свежесть -> [('Освежает лицо', 0.7767766714096069)] Освежает лицо
# Польирует -> [('Сужает поры', 0.7208623886108398)] Сужает поры
# Запах специфический -> [] None
# Оставляет жирность -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851033449172974)] Увлажняет надолго
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# ладан -> [] None
# стойкий аромат -> [('Легкий аромат', 0.7036257982254028)] Легкий аромат
# не липкий -> [('Не стягивает кожу', 0.7257087230682373)] Не стягивает кожу
# текстура приятная -> [('Удобный', 0.753629744052887)] Удобный
# на любителя -> [] None
# хорошее впитывание -> [('Увлажняет надолго', 0.703072726726532)] Увлажняет надолго
#
# Блестит -> [] None
# Смягчает кутикулу -> [('Мягко очищает', 0.7491069436073303)] Мягко очищает
# Быстро сохнет -> [('Быстро расходуется', 0.794741153717041)] Быстро расходуется
# Жесткая пила -> [] None
# Шероховатость -> [] None
#
# Качественное масло -> [] None
# Увлажняет -> [('Увлажняет надолго', 0.8851031064987183)] Увлажняет надолго
# Стильная упаковка -> [('Отличное качество', 0.70560622215271)] Отличное качество
# Липкое масло -> [] None
# Покрытие держится -> [('Увлажняет надолго', 0.7154791951179504)] Увлажняет надолго
# Пилка жесткая -> [] None
# Подходит для толстых ногтей -> [] None
# Удобная пилка -> [('Удобный', 0.7468101382255554)] Удобный
# Стойкий лак -> [] None
# Хорошее качество -> [('Отличное качество', 0.937332808971405)] Отличное качество
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Охлаждает -> [('Подсушивает', 0.7888526916503906)] Подсушивает
# Не липкий -> [('Не стягивает кожу', 0.7149156928062439)] Не стягивает кожу
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Удобный для путешествий -> [('Удобный', 0.813370406627655)] Удобный
#
# Увлажняет -> [('Увлажняет надолго', 0.8851033449172974)] Увлажняет надолго
# питает -> [('Питает кожу', 0.8369655609130859)] Питает кожу
# быстро впитывается -> [('Быстро расходуется', 0.7204931378364563)] Быстро расходуется
# для жирной кожи -> [('Для чувствительной кожи', 0.7961556315422058)] Для чувствительной кожи
# для сухой кожи -> [('Для сухих волос', 0.8601314425468445)] Для сухих волос
# не вызывает высыпаний -> [] None
# без комедогенности -> [] None
# с пинцетом -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Гладкие волосы -> [('Для сухих волос', 0.7191714644432068)] Для сухих волос
# Без силикона -> [] None
# Нет пленки -> [('Не оставляет пленки', 0.7182598114013672)] Не оставляет пленки
#
# Аллергия -> [] None
# Воспаление -> [] None
# Зуд -> [] None
# Плотная текстура -> [('Высокая плотность', 0.7380757927894592)] Высокая плотность
# Защита от солнца -> [] None
# Уменьшает пигментацию -> [('Мягко очищает', 0.7113511562347412)] Мягко очищает
# Водянистая текстура -> [] None
# Высокая защита -> [('Высокая плотность', 0.7198697328567505)] Высокая плотность
# Не устраняет пигментацию -> [] None
#
# Нежный -> [('Нежный', 1.0)] Нежный
# увлажняет -> [('Увлажняет надолго', 0.8867708444595337)] Увлажняет надолго
# мягкий -> [('Нежный', 0.7993518114089966)] Нежный
# питательный -> [] None
# держится плёнкой -> [('Подсушивает', 0.7073642015457153)] Подсушивает
# подходит под макияж -> [('Совместим с кремами', 0.7285982370376587)] Совместим с кремами
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Легко впитывается -> [] None
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Нежная кожа -> [('Нежный', 0.8042997717857361)] Нежный
# Питательный -> [] None
# Мягкая текстура -> [('Мягко очищает', 0.7483994364738464)] Мягко очищает
# Не засоряет поры -> [('Мягко очищает', 0.7120208740234375)] Мягко очищает
#
# Нейтральный запах -> [('Легкий аромат', 0.7224546670913696)] Легкий аромат
# Экономный расход -> [] None
# Для окрашенных волос -> [('Для сухих волос', 0.7545643448829651)] Для сухих волос
# Для пористых волос -> [('Для сухих волос', 0.7819869518280029)] Для сухих волос
# Длительное действие -> [] None
# Гладкость -> [] None
# Блеск -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# Легкий -> [('Удобный', 0.723291277885437)] Удобный
# Запах цветочный -> [('Легкий аромат', 0.705795407295227)] Легкий аромат
# Подходит для окрашенных -> [] None
# Нет хаоса -> [] None
# Универсальный запах -> [] None
#
# Удобный -> [('Удобный', 1.0000001192092896)] Удобный
# для спонжа -> [] None
# компактный -> [('Удобный', 0.7324634194374084)] Удобный
# не пачкает -> [('Не сушит', 0.7644907832145691)] Не сушит
# силиконовый -> [] None
# хранение -> [] None
# в дорогу -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Хороший эффект -> [('Выраженный эффект', 0.7732673287391663)] Выраженный эффект
# Мало нужно -> [] None
# Легко расчёсывается -> [('Мягко очищает', 0.7345781922340393)] Мягко очищает
#
# Серый оттенок -> [] None
# без окислителя -> [] None
# держится 2 недели -> [] None
# оттенок не по коже -> [('Не стягивает кожу', 0.701119065284729)] Не стягивает кожу
# требуется окислитель -> [] None
#
# Приятный аромат -> [('Легкий аромат', 0.872475266456604)] Легкий аромат
# Гладкие волосы -> [('Для сухих волос', 0.7191715240478516)] Для сухих волос
# Бюджетная цена -> [] None
#
# Щиплет веки -> [] None
# Аллергия -> [] None
# Ретинол -> [] None
# Раздражение -> [] None
#
# Хорошее качество -> [('Отличное качество', 0.9373326301574707)] Отличное качество
# Удерживает цвет -> [] None
# Без аллергии -> [] None
# Легко прокрашивает -> [('Мягко очищает', 0.7229436039924622)] Мягко очищает
#
# Матовая -> [] None
# стойкая -> [] None
# легко наносится -> [('Мягко очищает', 0.7424563765525818)] Мягко очищает
# короткая кисточка -> [] None
#
# Мягкий ворс -> [('Нежный', 0.7234194278717041)] Нежный
# Плотный ворс -> [] None
# Удобная кисть -> [('Удобный', 0.7980031371116638)] Удобный
# Хорошо наносит румяна -> [] None
# Не лезет -> [('Не стягивает кожу', 0.7597967982292175)] Не стягивает кожу
#
# Приятный аромат -> [('Легкий аромат', 0.8724752068519592)] Легкий аромат
# Хорошая фиксация -> [] None
# Легкий крем -> [('Легкий аромат', 0.7429100871086121)] Легкий аромат
# Без налета -> [] None
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Дешевый запах -> [('Легкий аромат', 0.7633337378501892)] Легкий аромат
# Сильный запах -> [] None
# Удобная щётка -> [('Удобный', 0.7733771800994873)] Удобный
#
# Увлажняет -> [('Увлажняет надолго', 0.8851031064987183)] Увлажняет надолго
# Питательное -> [] None
# Большое наполнение -> [('Даёт объём', 0.7156396508216858)] Даёт объём
# Удобно в дорогу -> [('Удобный', 0.8214740753173828)] Удобный
#
# Приятный аромат -> [('Легкий аромат', 0.8724751472473145)] Легкий аромат
# Стойкий запах -> [] None
#
# Пенится хорошо -> [('Хорошо пенится', 0.9163299202919006)] Хорошо пенится
# увлажняет -> [('Увлажняет надолго', 0.8867707252502441)] Увлажняет надолго
# шелковистые волосы -> [] None
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# для окрашенных волос -> [('Для сухих волос', 0.7481168508529663)] Для сухих волос
# экономичный расход -> [] None
# блестящие волосы -> [] None
# хорошая цена -> [('Отличное качество', 0.7236614227294922)] Отличное качество
# не схож с Hadat -> [] None
#
# Жирная голова -> [] None
# Освежающий аромат -> [('Легкий аромат', 0.8466542959213257)] Легкий аромат
# Рассыпчатые волосы -> [('Для сухих волос', 0.7064134478569031)] Для сухих волос
# Экономичный расход -> [] None
# Подходит для чувствительной кожи -> [('Для чувствительной кожи', 0.9406929016113281)] Для чувствительной кожи
# Очищает кожу головы -> [('Мягко очищает', 0.7249850034713745)] Мягко очищает
#
# Нежный аромат -> [('Легкий аромат', 0.8670821189880371)] Легкий аромат
# Деликатно отшелушивает -> [('Деликатно очищает', 0.884117603302002)] Деликатно очищает
# Шелк волосы -> [] None
#
# Гладкий результат -> [('Мягко очищает', 0.7289425134658813)] Мягко очищает
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Шелковистые волосы -> [] None
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Высокое качество -> [('Отличное качество', 0.9184988141059875)] Отличное качество
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Хорошо очищает -> [('Деликатно очищает', 0.9045785069465637)] Деликатно очищает
# Малый расход -> [] None
# Холодит -> [] None
# Подходит для жирной кожи головы -> [] None
#
# Приятный цвет -> [('Освежает лицо', 0.7555387020111084)] Освежает лицо
# мягкая текстура -> [('Мягко очищает', 0.7328671813011169)] Мягко очищает
# стойкая -> [] None
# увлажняет -> [('Увлажняет надолго', 0.8867708444595337)] Увлажняет надолго
# не растекается -> [('Не стягивает кожу', 0.736111044883728)] Не стягивает кожу
# соответствует описанию -> [] None
# нежный оттенок -> [('Нежный', 0.8551630973815918)] Нежный
# без блеска -> [] None
#
# Красивый цвет -> [('Освежает лицо', 0.7278209924697876)] Освежает лицо
# увлажняет -> [('Увлажняет надолго', 0.8867708444595337)] Увлажняет надолго
# не скатывается -> [('Не сушит', 0.7514423131942749)] Не сушит
# мягкая текстура -> [('Мягко очищает', 0.7328671813011169)] Мягко очищает
# держится долго -> [('Увлажняет надолго', 0.824768602848053)] Увлажняет надолго
# не сушит -> [('Не сушит', 0.9489961862564087)] Не сушит
# ложится ровно -> [] None
#
# Мягкая -> [('Нежный', 0.722463071346283)] Нежный
# Удобная -> [('Удобный', 0.8818777203559875)] Удобный
# Хорошая -> [('Отличное качество', 0.7305771708488464)] Отличное качество
# Для стрелок -> [] None
# Не лезут волоски -> [('Не стягивает кожу', 0.7078663110733032)] Не стягивает кожу
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Нет запаха -> [] None
# Впитывается мгновенно -> [] None
# Не вызывает аллергии -> [] None
# Не жирный -> [] None
#
# Компактные -> [] None
# Хорошее качество -> [('Отличное качество', 0.9373327493667603)] Отличное качество
# Удобно для макияжа -> [('Освежает лицо', 0.7401371002197266)] Освежает лицо
#
# Стойкая -> [] None
# Не сушит -> [('Не сушит', 1.000000238418579)] Не сушит
# Желтоватый подтон -> [] None
# Пятна не появляются -> [] None
# Суховатая текстура -> [('Подсушивает', 0.7511364817619324)] Подсушивает
# Цвет не соответствует -> [] None
# Приятный цвет -> [('Освежает лицо', 0.7555387616157532)] Освежает лицо
#
# Мягко промывает -> [('Мягко очищает', 0.9140498638153076)] Мягко очищает
# с дозатором -> [] None
# ежедневное использование -> [] None
#
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# Шелковистые -> [] None
# Не сушит -> [('Не сушит', 1.000000238418579)] Не сушит
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# Для тонких волос -> [('Для сухих волос', 0.8153120875358582)] Для сухих волос
# Сохраняет свежесть -> [('Освежает лицо', 0.7472617626190186)] Освежает лицо
#
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# закрепляет цвет -> [] None
# нужен дозатор -> [] None
#
# Лёгкий -> [('Удобный', 0.7076923847198486)] Удобный
# увлажняет -> [('Увлажняет надолго', 0.8867708444595337)] Увлажняет надолго
# впитывается -> [] None
# без жирного блеска -> [] None
# для аллергической кожи -> [('Для чувствительной кожи', 0.8909475207328796)] Для чувствительной кожи
# для комбинированной кожи -> [('Для чувствительной кожи', 0.8190909028053284)] Для чувствительной кожи
#
# Нежная -> [('Нежный', 0.863140344619751)] Нежный
# Очищает -> [('Деликатно очищает', 0.8635239601135254)] Деликатно очищает
# Не сушит -> [('Не сушит', 1.0000001192092896)] Не сушит
# Против акне -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851031064987183)] Увлажняет надолго
# Впитывается -> [] None
# Травяной аромат -> [('Легкий аромат', 0.7414229512214661)] Легкий аромат
# Натуральное масло -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# не сушит -> [('Не сушит', 0.9489964246749878)] Не сушит
# не забивает поры -> [('Не сушит', 0.7021927833557129)] Не сушит
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# сужает поры -> [('Сужает поры', 0.9039396047592163)] Сужает поры
# освежает -> [('Освежает дыхание', 0.9279187321662903)] Освежает дыхание
# мягкая кожа -> [('Для чувствительной кожи', 0.7316838502883911)] Для чувствительной кожи
#
# Цвет насыщенный -> [] None
# держится долго -> [('Увлажняет надолго', 0.824768602848053)] Увлажняет надолго
# легко наносится -> [('Мягко очищает', 0.7424563765525818)] Мягко очищает
# играет на солнце -> [] None
# снимается легко -> [('Мягко очищает', 0.7197322249412537)] Мягко очищает
# шимер присутствует -> [] None
#
# Цвет не как на фото -> [] None
# быстро сохнет -> [('Быстро расходуется', 0.7551624178886414)] Быстро расходуется
# ровно ложится -> [] None
# держится нормально -> [] None
# тонкий слой -> [] None
# чуть полосит -> [] None
#
# Твёрдые ногти -> [] None
# Матовый цвет -> [] None
# Слабое схватывание -> [('Слабое отшелушивание', 0.8058370351791382)] Слабое отшелушивание
# Не удерживает форму -> [('Не стягивает кожу', 0.7454686164855957)] Не стягивает кожу
# Не влияет на качество ногтей -> [] None
#
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# Хорошо смывается -> [('Деликатно очищает', 0.8294265866279602)] Деликатно очищает
# Плохо пенится -> [('Слабое отшелушивание', 0.7118619084358215)] Слабое отшелушивание
# Отлично справляется с перхотью -> [('Деликатно очищает', 0.7053521275520325)] Деликатно очищает
#
# Приятный цвет -> [('Освежает лицо', 0.7555387020111084)] Освежает лицо
# легко растушевывается -> [('Мягко очищает', 0.7013851404190063)] Мягко очищает
# не липкий -> [('Не стягивает кожу', 0.7257087230682373)] Не стягивает кожу
# естественный вид -> [] None
# ненавязчивый аромат -> [('Легкий аромат', 0.8878594040870667)] Легкий аромат
# нестойкий -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# не жирное -> [] None
# легкая консистенция -> [('Легкий аромат', 0.7478032112121582)] Легкий аромат
# увлажняет -> [('Увлажняет надолго', 0.8867707252502441)] Увлажняет надолго
# расчесывается легко -> [('Мягко очищает', 0.7506515979766846)] Мягко очищает
# мягкие волосы -> [('Для сухих волос', 0.7089810967445374)] Для сухих волос
# уменьшает пушок -> [] None
# ненавязчивый аромат -> [('Легкий аромат', 0.8878594040870667)] Легкий аромат
# экономный расход -> [] None
#
# Нежный аромат -> [('Легкий аромат', 0.8670821189880371)] Легкий аромат
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Мягкая пена -> [] None
# Нежирный крем -> [('Совместим с кремами', 0.725870668888092)] Совместим с кремами
# Стойкий запах -> [] None
# Гладкая кожа -> [('Мягко очищает', 0.7173491716384888)] Мягко очищает
#
# Ровная ложится -> [] None
# удобная кисточка -> [('Удобный', 0.7768399715423584)] Удобный
# не размазывается -> [('Не сушит', 0.725898802280426)] Не сушит
# легко смывается -> [('Мягко очищает', 0.8476642370223999)] Мягко очищает
#
# Мягкая текстура -> [('Мягко очищает', 0.7483992576599121)] Мягко очищает
# легко тушатся -> [('Мягко очищает', 0.7003340125083923)] Мягко очищает
# воздушная -> [] None
# нежные -> [('Нежный', 0.9168452024459839)] Нежный
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# устойчивый цвет -> [] None
# компактная упаковка -> [] None
# без блесток -> [] None
# держатся долго -> [('Увлажняет надолго', 0.7938586473464966)] Увлажняет надолго
# нейтральный тон -> [] None
#
# Хорошо тушится -> [] None
# Мягкий -> [('Нежный', 0.8240549564361572)] Нежный
# Красивый цвет -> [('Освежает лицо', 0.7278209924697876)] Освежает лицо
#
# Красивый цвет -> [('Освежает лицо', 0.7278209924697876)] Освежает лицо
# мягкий -> [('Нежный', 0.7993518114089966)] Нежный
# стойкий -> [] None
# не сушит -> [('Не сушит', 0.9489964246749878)] Не сушит
# растушевывается -> [('Подсушивает', 0.7332915663719177)] Подсушивает
# липкости нет -> [] None
# не растекается -> [('Не стягивает кожу', 0.7361109852790833)] Не стягивает кожу
#
# Мягкий -> [('Нежный', 0.8240550756454468)] Нежный
# Яркий -> [] None
# Легко наносится -> [('Мягко очищает', 0.7531207203865051)] Мягко очищает
# Стойкий -> [] None
# Розовый оттенок -> [] None
#
# Экономичный -> [] None
# ровно ложится -> [] None
# минимальный расход -> [] None
# без желтизны -> [] None
#
# Стильный цвет -> [('Освежает лицо', 0.7214954495429993)] Освежает лицо
# Нежная текстура -> [('Нежный', 0.7934879064559937)] Нежный
# Растекается -> [('Подсушивает', 0.7622795104980469)] Подсушивает
# Сушит губы -> [] None
# Стойкая -> [] None
# Насыщенный цвет -> [] None
# Тяжелая упаковка -> [] None
#
# Эффективный -> [] None
# Красный -> [] None
# Трудно выдавливать -> [] None
# Волосы крепче -> [] None
# Растут лучше -> [] None
#
# Матирует жирную кожу -> [('Питает кожу', 0.7020580768585205)] Питает кожу
# фиксирует макияж -> [] None
# натуральный цвет -> [] None
# малый расход -> [] None
# приятный аромат -> [('Легкий аромат', 0.8658909201622009)] Легкий аромат
# ложится ровно -> [] None
# сливается с кожей -> [('Питает кожу', 0.7245134115219116)] Питает кожу
#
# Тяжелый аромат -> [] None
# Нежный аромат -> [('Легкий аромат', 0.8670821189880371)] Легкий аромат
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# Блестящие волосы -> [] None
# Не утежеляет -> [] None
#
# Шелковый -> [] None
# Блестит -> [] None
# Яркий запах -> [('Легкий аромат', 0.7526242733001709)] Легкий аромат
# Гладкие -> [] None
# Мягкие -> [('Нежный', 0.7289742827415466)] Нежный
# Не жирнит -> [] None
# Экономичный расход -> [] None
# Для повреждённых волос -> [('Для сухих волос', 0.7572005391120911)] Для сухих волос
# Укладка на браш -> [] None
#
# Мало тоника -> [] None
# хорошо пенится -> [('Хорошо пенится', 0.9860424995422363)] Хорошо пенится
# не стягивает -> [('Не стягивает кожу', 0.870695948600769)] Не стягивает кожу
# гелевая текстура -> [] None
# успокаивает -> [('Освежает дыхание', 0.7574986219406128)] Освежает дыхание
# помогает с акне -> [] None
# подходит для комби кожи -> [('Совместим с кремами', 0.7102280855178833)] Совместим с кремами
#
# Кондиционер -> [] None
# Бальзам -> [] None
# Маска -> [] None
# Питает -> [('Питает кожу', 0.807714581489563)] Питает кожу
# Блестящие волосы -> [] None
# Пахнет цветами -> [('Легкий аромат', 0.7278497219085693)] Легкий аромат
#
# Не склеивает -> [('Не стягивает кожу', 0.7814462184906006)] Не стягивает кожу
# средняя фиксация -> [] None
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# мелкое распыление -> [] None
# держится два часа -> [] None
# для тонких волос -> [('Для сухих волос', 0.8073679208755493)] Для сухих волос
# упаковка не защищает -> [] None
#
# Не склеивает -> [('Не стягивает кожу', 0.781446099281311)] Не стягивает кожу
# Легко расчёсывается -> [('Мягко очищает', 0.7345781326293945)] Мягко очищает
# Хорошо фиксирует -> [] None
#
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# хорошо пенится -> [('Хорошо пенится', 0.9860424995422363)] Хорошо пенится
# мягкие волосы -> [('Для сухих волос', 0.7089811563491821)] Для сухих волос
# очищает кожу головы -> [('Мягко очищает', 0.727441668510437)] Мягко очищает
# не спутывает волосы -> [('Не сушит', 0.7571864128112793)] Не сушит
# маленький расход -> [] None
#
# Пенится хорошо -> [('Хорошо пенится', 0.9163299202919006)] Хорошо пенится
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# питательный -> [] None
# не утяжеляет волосы -> [] None
# подходит для окрашенных волос -> [('Для сухих волос', 0.7000073194503784)] Для сухих волос
# экономичен -> [('Удобный', 0.7007825374603271)] Удобный
# очищает кожу головы -> [('Мягко очищает', 0.7274415493011475)] Мягко очищает
# шелковистые волосы -> [] None
#
# Плотная -> [] None
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Питает -> [('Питает кожу', 0.807714581489563)] Питает кожу
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Экономичный расход -> [] None
# Восстанавливает структуру -> [] None
# Распутывает -> [('Подсушивает', 0.7619568705558777)] Подсушивает
# Разглаживает -> [('Мягко очищает', 0.7622421979904175)] Мягко очищает
#
# Не липкий -> [('Не стягивает кожу', 0.7149156928062439)] Не стягивает кожу
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Стильный блеск -> [] None
# Долго держится -> [('Увлажняет надолго', 0.8078200221061707)] Увлажняет надолго
# Приятный аромат -> [('Легкий аромат', 0.8724752068519592)] Легкий аромат
#
# Увлажняет -> [('Увлажняет надолго', 0.8851033449172974)] Увлажняет надолго
# Питает -> [('Питает кожу', 0.807714581489563)] Питает кожу
# Нежная кожа -> [('Нежный', 0.8042997717857361)] Нежный
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Быстро впитывается -> [('Быстро расходуется', 0.7235440015792847)] Быстро расходуется
# Смягчает -> [('Мягко очищает', 0.7839870452880859)] Мягко очищает
# Удобный набор -> [('Удобный', 0.8192040324211121)] Удобный
# Хорошее упаковка -> [('Отличное качество', 0.7521353960037231)] Отличное качество
# Жирный крем -> [] None
#
# Мягкая кожа -> [('Для чувствительной кожи', 0.7509624361991882)] Для чувствительной кожи
# Результат заметный -> [('Выраженный эффект', 0.805286169052124)] Выраженный эффект
# Удобный уход -> [('Удобный', 0.8276073336601257)] Удобный
# Длительный эффект -> [('Выраженный эффект', 0.7373762130737305)] Выраженный эффект
# Хорошее качество -> [('Отличное качество', 0.9373326897621155)] Отличное качество
#
# Справляется с прыщами -> [('Совместим с кремами', 0.7134209871292114)] Совместим с кремами
# Уменьшает высыпания -> [] None
# Без раздражения -> [] None
# Чистит кожу -> [('Мягко очищает', 0.8326879143714905)] Мягко очищает
# Пользуется для проблемной кожи -> [('Для чувствительной кожи', 0.7396227121353149)] Для чувствительной кожи
#
# Быстро впитывается -> [('Быстро расходуется', 0.7235440015792847)] Быстро расходуется
# Не липнет -> [('Не стягивает кожу', 0.8126723766326904)] Не стягивает кожу
# Хорошо питает кожу -> [('Питает кожу', 0.878309965133667)] Питает кожу
# Под глазки -> [] None
# Для морщин -> [] None
#
# Работает от батареек -> [] None
# Массаж по линиям -> [] None
# Шарик заедает -> [] None
# Качество ухудшается -> [] None
# Сломался быстро -> [('Быстро расходуется', 0.7665141820907593)] Быстро расходуется
# Пользуется редко -> [] None
#
# Лёгкий -> [('Удобный', 0.7076923251152039)] Удобный
# приятный запах -> [('Легкий аромат', 0.8495476841926575)] Легкий аромат
# хорошо впитывается -> [('Увлажняет надолго', 0.7599758505821228)] Увлажняет надолго
# не сушит -> [('Не сушит', 0.9489969611167908)] Не сушит
# экономичный расход -> [] None
#
# Тон светлый -> [] None
# Лёгкая текстура -> [('Легкий аромат', 0.7675089240074158)] Легкий аромат
# Не чувствуется на коже -> [('Не стягивает кожу', 0.8204225897789001)] Не стягивает кожу
# Держится 5-6 часов -> [] None
# Подходит для 50+ -> [] None
#
# Оригинал -> [] None
# Спирт -> [] None
# Немного липнет -> [('Подсушивает', 0.7141352891921997)] Подсушивает
# Удобный формат -> [('Удобный', 0.7919253706932068)] Удобный
# Меньше качества -> [] None
#
# Мягкая -> [('Нежный', 0.722463071346283)] Нежный
# маслянистая -> [] None
# не липнет -> [('Не стягивает кожу', 0.8067159652709961)] Не стягивает кожу
# не растекается -> [('Не стягивает кожу', 0.736111044883728)] Не стягивает кожу
# увлажняющая -> [('Увлажняет надолго', 0.7614566683769226)] Увлажняет надолго
# держится хорошо -> [('Увлажняет надолго', 0.7074372172355652)] Увлажняет надолго
# приятная на губах -> [('Освежает лицо', 0.7060067057609558)] Освежает лицо
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# мягкие волосы -> [('Для сухих волос', 0.7089811563491821)] Для сухих волос
# шелковистые -> [] None
# ненавязчивый аромат -> [('Легкий аромат', 0.8878594636917114)] Легкий аромат
# питает -> [('Питает кожу', 0.8369658589363098)] Питает кожу
# для пористых волос -> [('Для сухих волос', 0.7737723588943481)] Для сухих волос
#
# Выравнивает -> [] None
# Убирает покраснения -> [('Мягко очищает', 0.7171193957328796)] Мягко очищает
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Сушит -> [] None
# Точечное нанесение -> [] None
# Подходит для жирной кожи -> [('Для чувствительной кожи', 0.7673973441123962)] Для чувствительной кожи
#
# Не сушит -> [('Не сушит', 1.0000001192092896)] Не сушит
# Не раздражает -> [] None
# Для сухой кожи -> [('Для сухих волос', 0.8607179522514343)] Для сухих волос
# Хорошо очищает -> [('Деликатно очищает', 0.9045783877372742)] Деликатно очищает
#
# Деликатный -> [] None
# ...
#
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# нестойкий -> [] None
# лёгкий аромат -> [('Легкий аромат', 0.9396352171897888)] Легкий аромат
# стеклянный флакон -> [] None
# сладкий аромат -> [('Легкий аромат', 0.7769457101821899)] Легкий аромат
#
# Яркий цвет -> [('Освежает лицо', 0.7255512475967407)] Освежает лицо
# Наносится легко -> [('Мягко очищает', 0.7561871409416199)] Мягко очищает
# Удлинение -> [('Удлиняет ресницы', 0.7093768119812012)] Удлиняет ресницы
# Объём -> [('Даёт объём', 0.8053374290466309)] Даёт объём
# Голубой цвет -> [] None
#
# SPF 20 -> [] None
# Легко наносится -> [('Мягко очищает', 0.7531207203865051)] Мягко очищает
# Быстро впитывается -> [('Быстро расходуется', 0.7235440015792847)] Быстро расходуется
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Не жирный -> [] None
# Нежная кожа -> [('Нежный', 0.8042999505996704)] Нежный
#
# Приятный аромат -> [('Легкий аромат', 0.872475266456604)] Легкий аромат
# Стойкий запах -> [] None
# Не стягивает кожу -> [('Не стягивает кожу', 1.0000001192092896)] Не стягивает кожу
#
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# Пенится хорошо -> [('Хорошо пенится', 0.9163299798965454)] Хорошо пенится
# Сушит волосы -> [('Подсушивает', 0.8268678188323975)] Подсушивает
# Для сухих волос -> [('Для сухих волос', 0.9999998807907104)] Для сухих волос
# Слабое питание -> [] None
#
# Стойкий аромат -> [('Легкий аромат', 0.7350910902023315)] Легкий аромат
# яркий запах -> [] None
# свежесть -> [('Освежает лицо', 0.7700538039207458)] Освежает лицо
# цитрус -> [] None
# неплохой запах -> [('Легкий аромат', 0.8255976438522339)] Легкий аромат
#
# Сладковатый -> [] None
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Не сильно стойкий -> [('Слабое отшелушивание', 0.730762243270874)] Слабое отшелушивание
# Отличный аромат -> [('Легкий аромат', 0.8157461881637573)] Легкий аромат
#
# Мягкая текстура -> [('Мягко очищает', 0.7483994364738464)] Мягко очищает
# хорошо пенится -> [('Хорошо пенится', 0.9860424995422363)] Хорошо пенится
# не сушит кожу -> [('Не сушит', 0.7943794131278992)] Не сушит
# снимает макияж -> [] None
# комфортная пенка -> [('Удобный', 0.7407677173614502)] Удобный
# экономичный расход -> [] None
#
# Удобный в путешествии -> [('Удобный', 0.8378217220306396)] Удобный
# Мини формат -> [] None
# Комфортно в поездке -> [('Удобный', 0.7855004668235779)] Удобный
#
# Снимает воспаление -> [] None
# Без аллергии -> [] None
# Для ночного использования -> [('Для ночного ухода', 0.8757530450820923)] Для ночного ухода
#
# Липкий -> [] None
# Яркий цвет -> [('Освежает лицо', 0.7255512475967407)] Освежает лицо
# Карамельный запах -> [] None
# Не скатывается -> [('Не сушит', 0.776350200176239)] Не сушит
# Удобный нанесение -> [('Удобный', 0.7791296243667603)] Удобный
#
# Деликатный блеск -> [('Деликатно очищает', 0.7448905110359192)] Деликатно очищает
# Легкий блеск -> [('Легкий аромат', 0.7880474328994751)] Легкий аромат
# Ненавязчивый блеск -> [] None
# Универсальный блеск -> [] None
#
# Жидкая текстура -> [] None
# впитывается -> [] None
# шелковистая кожа -> [] None
# лёгкий крем -> [('Совместим с кремами', 0.7433860898017883)] Совместим с кремами
# удобный дозатор -> [('Удобный', 0.7664229273796082)] Удобный
#
# Стойкий аромат -> [('Легкий аромат', 0.7350911498069763)] Легкий аромат
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# Не оставляет следов -> [('Не оставляет пленки', 0.8116406202316284)] Не оставляет пленки
# Защищает от пота -> [] None
#
# Аромат шикарный -> [('Легкий аромат', 0.7473943829536438)] Легкий аромат
# Не пенится -> [('Не сушит', 0.7182844877243042)] Не сушит
# Запах держится мало -> [('Легкий аромат', 0.7120198011398315)] Легкий аромат
#
# Зелёный аромат -> [] None
# горькая нота -> [] None
# базилик -> [] None
# сладкий -> [] None
# не свежий -> [('Не сушит', 0.7072491645812988)] Не сушит
# крышка не закрывается ровно -> [] None
# качество не оригинал -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# стойкий -> [] None
# ненавязчивый -> [('Нежный', 0.7204461097717285)] Нежный
# ваниль -> [] None
# бархатный -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# быстро впитывается -> [('Быстро расходуется', 0.7204931378364563)] Быстро расходуется
# стойкий запах -> [] None
# приятный аромат -> [('Легкий аромат', 0.8658909797668457)] Легкий аромат
# не оставляет жирности -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571909070014954)] Легкий аромат
# сладко-кислый аромат -> [('Легкий аромат', 0.767394483089447)] Легкий аромат
# не душный -> [('Не сушит', 0.7778438329696655)] Не сушит
#
# Не пенится -> [('Не сушит', 0.7182842493057251)] Не сушит
# Спутывает волосы -> [('Подсушивает', 0.7448521852493286)] Подсушивает
# Без эластичности -> [] None
# Без блеска -> [] None
# Плотно пенится -> [('Хорошо пенится', 0.8494536876678467)] Хорошо пенится
# Приятный аромат -> [('Легкий аромат', 0.8724752068519592)] Легкий аромат
# Шелковистые волосы -> [] None
# Придает мягкость -> [('Мягко очищает', 0.7882777452468872)] Мягко очищает
# Волосы выглядят ухоженными -> [('Освежает лицо', 0.7883069515228271)] Освежает лицо
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# выравнивает тон -> [] None
# осветляет пигментацию -> [] None
# не липнет -> [('Не стягивает кожу', 0.8067159652709961)] Не стягивает кожу
# быстро впитывается -> [('Быстро расходуется', 0.7204931378364563)] Быстро расходуется
# приятный аромат -> [('Легкий аромат', 0.8658909201622009)] Легкий аромат
# для чувствительной кожи -> [('Для чувствительной кожи', 0.9914661049842834)] Для чувствительной кожи
# эффективно борется с веснушками -> [] None
#
# Волшебный запах -> [('Легкий аромат', 0.7286285161972046)] Легкий аромат
# шлейфовый -> [] None
# нестойкий -> [] None
# мужские ноты -> [] None
# женственные ноты -> [] None
# кедр -> [] None
# хвоя -> [] None
# стойкий -> [] None
# нежный -> [('Нежный', 0.9741476774215698)] Нежный
# оригинальный -> [] None
#
# Яркий -> [] None
# Мелкие блестки -> [] None
# Маленький флакон -> [] None
# Высокий блеск -> [('Высокая плотность', 0.736258327960968)] Высокая плотность
#
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Увлажняет -> [('Увлажняет надолго', 0.8851031064987183)] Увлажняет надолго
# Смягчает кожу -> [('Мягко очищает', 0.7951496243476868)] Мягко очищает
# Крышка закрыта -> [('Подсушивает', 0.7139955759048462)] Подсушивает
#
# Коричневый цвет -> [] None
# без комочков -> [] None
# не осыпается -> [('Не сушит', 0.742280125617981)] Не сушит
# не склеивает -> [('Не стягивает кожу', 0.7772094011306763)] Не стягивает кожу
# легко смывается -> [('Мягко очищает', 0.8476641178131104)] Мягко очищает
# удлиняет -> [('Удлиняет ресницы', 0.8089801073074341)] Удлиняет ресницы
#
# Красивая упаковка -> [('Освежает лицо', 0.7034605741500854)] Освежает лицо
# Твердая упаковка -> [] None
# Хорошее наполнение -> [('Отличный состав', 0.7996652126312256)] Отличный состав
# Красивый дизайн -> [('Отличное качество', 0.7297383546829224)] Отличное качество
#
# Жидкий крем -> [] None
# Легко выравнивает тон -> [('Мягко очищает', 0.7784072160720825)] Мягко очищает
# Маскирует -> [('Подсушивает', 0.737054705619812)] Подсушивает
# Не увлажняет -> [('Не стягивает кожу', 0.83659428358078)] Не стягивает кожу
# Подходит для светлой кожи -> [('Для чувствительной кожи', 0.7499134540557861)] Для чувствительной кожи
# Похож на bb-крем -> [] None
# Сухой запах -> [] None
#
# Единороги -> [] None
# удобная -> [('Удобный', 0.8710335493087769)] Удобный
# для детских волос -> [('Для сухих волос', 0.7756478190422058)] Для сухих волос
# не рвёт -> [('Не сушит', 0.7303152084350586)] Не сушит
# легкая -> [('Легкий аромат', 0.7148513197898865)] Легкий аромат
# симпатичная -> [('Освежает лицо', 0.7089399099349976)] Освежает лицо
# хорошее расчесывание -> [('Деликатно очищает', 0.7195313572883606)] Деликатно очищает
#
# Не дерет волосы -> [] None
# для длинных волос -> [('Для сухих волос', 0.7783244848251343)] Для сухих волос
# гладко по мокрым -> [('Мягко очищает', 0.7333101034164429)] Мягко очищает
# удобная -> [('Удобный', 0.8710335493087769)] Удобный
# не цепляет -> [('Не стягивает кожу', 0.8174459338188171)] Не стягивает кожу
# оригинальная -> [] None
# яркий цвет -> [] None
#
# Жесткая -> [] None
# Легкая -> [] None
# Прочесывает -> [('Подсушивает', 0.8128985166549683)] Подсушивает
# Сушит быстро -> [('Не сушит', 0.7625108957290649)] Не сушит
# Мягко расчесывает -> [('Мягко очищает', 0.8308732509613037)] Мягко очищает
# Для длинных волос -> [('Для сухих волос', 0.7859323024749756)] Для сухих волос
# Справляется с корнями -> [] None
# Многофункциональная -> [] None
# Удобная в руке -> [('Удобный', 0.748344898223877)] Удобный
# Поток воздуха -> [('Освежает дыхание', 0.7343485951423645)] Освежает дыхание
#
# Блестит -> [] None
# приятные на ощупь -> [('Освежает лицо', 0.7826883792877197)] Освежает лицо
# сушит волосы -> [('Подсушивает', 0.7927157878875732)] Подсушивает
# слабо закручен -> [('Слабое отшелушивание', 0.7533198595046997)] Слабое отшелушивание
# пролилось -> [('Подсушивает', 0.7187820076942444)] Подсушивает
#
# Мягкие волосы -> [('Для сухих волос', 0.7207173109054565)] Для сухих волос
# Увлажнение -> [('Увлажняет надолго', 0.7695482969284058)] Увлажняет надолго
# Питает -> [('Питает кожу', 0.807714581489563)] Питает кожу
# Нежный аромат -> [('Легкий аромат', 0.8670821189880371)] Легкий аромат
# Быстро впитывается -> [('Быстро расходуется', 0.7235440015792847)] Быстро расходуется
# Не утяжеляет -> [('Мягко очищает', 0.7067421674728394)] Мягко очищает
# Плотные волосы -> [] None
# Работает -> [('Даёт объём', 0.7298365831375122)] Даёт объём
#
# Мягкое -> [('Нежный', 0.7556148767471313)] Нежный
# для чувствительной кожи -> [('Для чувствительной кожи', 0.9914661049842834)] Для чувствительной кожи
# снимает макияж -> [] None
# не сушит кожу -> [('Не сушит', 0.794379472732544)] Не сушит
# без запаха -> [] None
# увлажняет -> [('Увлажняет надолго', 0.8867707252502441)] Увлажняет надолго
# комфортно -> [('Удобный', 0.8165654540061951)] Удобный
# эффективное -> [('Выраженный эффект', 0.7116506099700928)] Выраженный эффект
# для глаз -> [('Освежает лицо', 0.7089411616325378)] Освежает лицо
# снимает тушь -> [] None
#
# Маслянистый -> [] None
# Ненавязчивый запах -> [('Легкий аромат', 0.8514944314956665)] Легкий аромат
# Коричневый загар -> [] None
# Защита от УФ -> [] None
# Впитывается не быстро -> [('Не стягивает кожу', 0.709105372428894)] Не стягивает кожу
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Охлаждает -> [('Подсушивает', 0.7888526916503906)] Подсушивает
# Быстро впитывается -> [('Быстро расходуется', 0.7235440015792847)] Быстро расходуется
# Дозатор -> [] None
# Снимает отеки -> [] None
#
# Скатывается -> [('Подсушивает', 0.7115834951400757)] Подсушивает
# Легкий -> [('Удобный', 0.7232913970947266)] Удобный
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Питает -> [('Питает кожу', 0.807714581489563)] Питает кожу
# Мягкая текстура -> [('Мягко очищает', 0.7483992576599121)] Мягко очищает
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Не липнет -> [('Не стягивает кожу', 0.8126722574234009)] Не стягивает кожу
# Хорошо впитывается -> [('Увлажняет надолго', 0.7607879638671875)] Увлажняет надолго
# Без жирности -> [] None
# Сладкий аромат -> [('Легкий аромат', 0.7852351665496826)] Легкий аромат
#
# Оригинал -> [] None
# Мятая коробка -> [] None
# Повреждённая упаковка -> [] None
#
# Приятное ощущение -> [('Освежает дыхание', 0.7667967677116394)] Освежает дыхание
# Впитывается -> [] None
# Для сухой кожи -> [('Для сухих волос', 0.8607178926467896)] Для сухих волос
#
# Аромат -> [('Легкий аромат', 0.7494361400604248)] Легкий аромат
# Не стойкий -> [('Не стягивает кожу', 0.7409194111824036)] Не стягивает кожу
# Популярный запах -> [('Легкий аромат', 0.734989583492279)] Легкий аромат
#
# Уютный аромат -> [('Легкий аромат', 0.868376612663269)] Легкий аромат
# Запах черники -> [] None
# Запах пекарни -> [] None
# Планируется подарок -> [] None
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# убирает покраснения -> [('Мягко очищает', 0.7150307893753052)] Мягко очищает
# ненавязчивый запах -> [('Легкий аромат', 0.8605027794837952)] Легкий аромат
# питает кожу -> [('Питает кожу', 0.9830609560012817)] Питает кожу
# натуральный состав -> [] None
# минимальный расход -> [] None
#
# Натуральный состав -> [] None
# Розовый цвет -> [] None
# Ухаживающие компоненты -> [] None
# Мягкий вкус -> [('Легкий аромат', 0.8397657871246338)] Легкий аромат
# Не пенится -> [('Не сушит', 0.7182842493057251)] Не сушит
# Чистит десна -> [('Деликатно очищает', 0.7540234327316284)] Деликатно очищает
# Освежает -> [('Освежает дыхание', 0.927131712436676)] Освежает дыхание
# Без аллергии -> [] None
# Минимальный расход -> [] None
# Чувство чистоты -> [('Мягко очищает', 0.737828254699707)] Мягко очищает
#
# Увлажняет -> [('Увлажняет надолго', 0.8851032257080078)] Увлажняет надолго
# Сильный запах -> [] None
# Подходит для комбинированной кожи -> [('Для чувствительной кожи', 0.7864971160888672)] Для чувствительной кожи
# Плотный крем -> [] None
#
# Не жирнит -> [] None
# Уменьшает выпадение -> [] None
# Пользуется долго -> [('Увлажняет надолго', 0.7727944254875183)] Увлажняет надолго
# Приятный аромат -> [('Легкий аромат', 0.8724750280380249)] Легкий аромат
# Крепкие волосы -> [] None
#
# Мятный запах -> [('Легкий аромат', 0.8631508350372314)] Легкий аромат
# Не пенится -> [('Не сушит', 0.7182843685150146)] Не сушит
# Коричневая паста -> [] None
# Зубы желтее -> [] None
# Отбеливает -> [('Освежает лицо', 0.7643150091171265)] Освежает лицо
# Соленый вкус -> [] None
#
# Мятный аромат -> [('Легкий аромат', 0.8651162385940552)] Легкий аромат
# без пены -> [] None
# растительный состав -> [] None
# безопасный состав -> [] None
# не сушит рот -> [('Не сушит', 0.8295334577560425)] Не сушит
# алкоголь на любителя -> [] None
# освежает -> [('Освежает дыхание', 0.9279189705848694)] Освежает дыхание
# очищает -> [('Деликатно очищает', 0.8896698951721191)] Деликатно очищает
# экологичная паста -> [] None
# для любителей без фтора -> [] None
#
# Приятный аромат -> [('Легкий аромат', 0.8724751472473145)] Легкий аромат
# свежий -> [('Освежает дыхание', 0.7667515277862549)] Освежает дыхание
# стойкий -> [] None
# освежающий -> [('Освежает дыхание', 0.8960399627685547)] Освежает дыхание
# сладкий -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Не стойкий -> [('Не стягивает кожу', 0.7409193515777588)] Не стягивает кожу
#
# Стойкий -> [] None
# Подтекает -> [('Подсушивает', 0.8113163709640503)] Подсушивает
# Старый аромат -> [] None
# Низкая стойкость -> [('Слабое отшелушивание', 0.7572479248046875)] Слабое отшелушивание
# Оригинал -> [] None
# Упаковка презентабельна -> [('Освежает лицо', 0.731864333152771)] Освежает лицо
# Пахнет перцем -> [] None
# Можжевельник -> [] None
# Шикарная скидка -> [] None
#
# Лёгкая -> [('Легкий аромат', 0.7029447555541992)] Легкий аромат
# хорошо расчёсывает -> [('Даёт объём', 0.7345770001411438)] Даёт объём
# не дергает -> [] None
# устойчивая упаковка -> [] None
#
# Замочок отломан -> [] None
# Цвет бледный -> [] None
# Надписи нет -> [] None
# Качество на высоте -> [('Отличное качество', 0.783087432384491)] Отличное качество
# Не искажает -> [] None
#
# Нежный -> [('Нежный', 1.0)] Нежный
# стеклянный -> [] None
# сирень -> [] None
# уютный -> [('Удобный', 0.8509326577186584)] Удобный
# тёплый -> [('Удобный', 0.7301343083381653)] Удобный
# лёгкий -> [('Удобный', 0.7530470490455627)] Удобный
# цветочный -> [] None
#
# Без комков -> [] None
# Не склеивает -> [('Не стягивает кожу', 0.7814462184906006)] Не стягивает кожу
# Уходовое действие -> [] None
# Не сухая -> [('Не сушит', 0.8379087448120117)] Не сушит
# Средняя кисточка -> [] None
#
# Приятный запах -> [('Легкий аромат', 0.8571908473968506)] Легкий аромат
# Качественная упаковка -> [('Отличное качество', 0.7970718741416931)] Отличное качество
# Свежесть кожи -> [('Освежает лицо', 0.7996102571487427)] Освежает лицо
# Мини версия -> [] None
#
# Очищает до скрипа -> [('Деликатно очищает', 0.7737041711807251)] Деликатно очищает
# Не травмирует кожу -> [('Не стягивает кожу', 0.7182558178901672)] Не стягивает кожу
# Малый расход -> [] None
# Оригинальный товар -> [('Отличное качество', 0.7131123542785645)] Отличное качество

# %%
for i in range(10):
    print(final[i][1])
# Out:
# ['Питает кожу', 'Мягко очищает', 'Увлажняет надолго', 'Не стягивает кожу', 'Высокая плотность', 'Легкий аромат', 'Быстро расходуется']
# ['Подсушивает', 'Увлажняет надолго', 'Не стягивает кожу', 'Удобный', 'Легкий аромат']
# ['Мягко очищает', 'Легкий аромат', 'Увлажняет надолго', 'Быстро расходуется']
# ['Легкий аромат', 'Увлажняет надолго', 'Не стягивает кожу']
# ['Удобный', 'Легкий аромат', 'Увлажняет надолго', 'Быстро расходуется']
# ['Мягко очищает', 'Даёт объём', 'Увлажняет надолго', 'Быстро расходуется', 'Не сушит']
# ['Освежает лицо', 'Легкий аромат']
# ['Мягко очищает', 'Легкий аромат', 'Удлиняет ресницы']
# ['Подсушивает', 'Для сухих волос', 'Отличное качество']
# ['Освежает лицо']

# %%
final[0]
# Out:
# ('Стильная, приятная по ощущениям.\nТёплый удобный\nХорошая, рекомендую\nОчень колючая\nОтлично смотрится. заказал вторую такую же.\nКлассево выглядит, состав шикарный!\nХорошая, лёгкая шапка. Качество на уровне\n',
#  ['Приятная ткань', 'Держит тепло', 'Легко стирается', 'Качественный'])

# %%
len(final)
# Out:
# 1793

# %%
import csv
import json

name = "beauty_dataset1800.csv"

with open(name, "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f)
    writer.writerow(["text", "tags"])  # заголовки

    for text, tags in final:
        writer.writerow([text, json.dumps(tags, ensure_ascii=False)])

# %%
bags500 = pd.read_csv(name)
bags500
# Out:
#                                                    text  \
# 0     ["Хороший крем", "Крем понравился, хорошо увла...
# 1     ["Приятный запах, не липкое", "Губы увлажненны...
# 2     ["Отличный скраб, запах очень приятный, спасиб...
# 3     ["Оригинал! Цвет огонь!", "Классный блеск, пря...
# 4     ["Запах восхитительный. Средства свои функции ...
# ...                                                 ...
# 1788  Пришло с отломанным замочком. Цвет бледный, вы...
# 1789  потрясный аромат\nНе навязчивый стойкий\nАрома...
# 1790  Очень деликатное нанесение , без комков , не с...
# 1791  Запах приятный, пока тестирую\nДавно хотела по...
# 1792  Самый лучший скраб который я пробовала \nЛучши...
#
#                                                    tags
# 0     ["Питает кожу", "Мягко очищает", "Увлажняет на...
# 1     ["Подсушивает", "Увлажняет надолго", "Не стяги...
# 2     ["Мягко очищает", "Легкий аромат", "Увлажняет ...
# 3     ["Легкий аромат", "Увлажняет надолго", "Не стя...
# 4     ["Удобный", "Легкий аромат", "Увлажняет надолг...
# ...                                                 ...
# 1788                              ["Отличное качество"]
# 1789                              ["Удобный", "Нежный"]
# 1790                  ["Не сушит", "Не стягивает кожу"]
# 1791  ["Освежает лицо", "Легкий аромат", "Отличное к...
# 1792  ["Отличное качество", "Деликатно очищает", "Не...
#
# [1793 rows x 2 columns]
